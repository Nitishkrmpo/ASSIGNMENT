# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns #statistical data visualization

# %%
#seaborn is little bit more advamce than matplotlib
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df =sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#numerical data plotting 
sns.relplot(x='total_bill', y ='tip', data=df )

# %%
#by default the relplot give the scatter plot belation between the  y and x  axis
sns.scatterplot(x=df.total_bill, y=df.tip, data = df )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#hue has differentiated between the smoker and non smoker in the dataset 
sns.scatterplot(x=df.total_bill, y=df.tip, data = df,hue = 'smoker' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#as the bills increase , the tips increases 
#highest tips was apid by the smoker 
sns.scatterplot(x='total_bill', y='tip', data = df,hue = 'smoker' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='tip', data= df , style ='smoker', hue= 'time')  
#hue is in color coding of same dataobject here (time)
#style is for change the type of symbol used for coding

# %%
sns.relplot(x='total_bill', y='tip', data= df , hue ='smoker')  
#check at 15 : 30

# %%
sns.relplot(x='total_bill', y='tip', data= df , hue='size')

# %%
sns.relplot(x='total_bill', y='tip', data= df ,style='smoker', hue='time')

# %%
#relplot to make a line plot >> we generated a data
time = np.arange(500)
value=np.random.randn(500).cumsum()
df = pd.DataFrame({'time': time , 'value': value})

# %%
df
# Out:
#      time     value
# 0       0  0.382630
# 1       1  1.006098
# 2       2  0.178713
# 3       3  0.749909
# 4       4  0.283248
# ..    ...       ...
# 495   495  4.095739
# 496   496  3.783612
# 497   497  3.678087
# 498   498  4.016251
# 499   499  2.785028
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='time', y='value',kind='line', data=df, sort = True)

# %%
fmri= sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint', y='signal', kind ='line', data =fmri, ci = 'sd')
# Out:
# C:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
#if we want to remove ci as the parameter
sns.relplot(x='timepoint', y='signal', estimator=None, kind ='line', data =fmri, ci = 'sd')
# Out:
# C:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x='timepoint', y='signal',  kind ='line', data =fmri,hue ='event')

# %%
sns.relplot(x='timepoint', y='signal',  kind ='line', data =fmri,hue ='event',style= 'region')

# %%
sns.relplot(x='timepoint', y='signal',  kind ='line', data =fmri,hue ='event', style= 'region',markers=True, dashes= False)

# %%
tips=sns.load_dataset('tips')

# %%
sns.relplot(x='total_bill', y='tip', hue ='smoker', data=tips, col='time')

# %%
sns.relplot(x='total_bill', y='tip', hue ='smoker', data=tips, col='size')

# %%
sns.scatterplot(x='total_bill', y='tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day', y='total_bill', data=tips)

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'swarm')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'box')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'violin')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'boxen')

# %%
sns.barplot(x='day', y ='total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x=tips.total_bill, y= tips.tip) #raw a plot  of two variable with the bivarite and univariate graphs.

# %%
sns.jointplot(x=tips.total_bill, y= tips.tip, kind ='reg')

# %%
sns.jointplot(x=tips.total_bill, y= tips.tip, kind ='hex')

# %%
sns.jointplot(x=tips.total_bill, y= tips.tip, kind ="kde") #kernal density estimato <contour_plot> also used in metrollogical department

# %%
#pairplot >> it  will plot all the pair wise  relationship btw dataframes 
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue ='smoker')

# %%
sns.pairplot(tips,hue='smoker',palette='coolwarm')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#boxplot 
sns.boxplot(x='day', y='total_bill', data=tips, palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot( data=tips, palette='rainbow', orient ='h')
# Out:
# <Axes: >

# %%
tips = tips[['total_bill','tip','size']]

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(),cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.heatmap(tips.corr(),cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x="total_bill", y='tip', data=df)

# %%
sns.lmplot(x="total_bill", y='tip', data=df, height = 15)

# %%
sns.lmplot(x="total_bill", y='tip', data=df, height = 15,aspect=0.5)

# %%
sns.lmplot(x="total_bill", y='tip', data=df, height = 15,aspect=1)
